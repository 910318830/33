# %%
import pandas as pd
import numpy as np

# %%
#任务1：将列表转化为Numpy数据
date0=[2,3,4,5.5,6]
arr0=np.array(date0)

# %%
s = pd.Series(data=[100,'a',{'dic1':5}],
            index=pd.Index(['id1',20,'third'],name='my_idx'),
            dtype='object',
            name='my_name')

# %%
s2=pd.Series(["1","2","3","4"])

# %%
s2.index.values
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
s2.values
# Out:
# array(['1', '2', '3', '4'], dtype=object)

# %%
d1={
    "作者":pd.Series(['余华','残雪','莫言']),
    "作品":pd.Series(['活着','暗夜','红高粱']),
    "价格":pd.Series(['25','45','55']),
}
df2=pd.DataFrame(d1)

# %%
#任务2：创建DataFrame类型的数据，并获取其索引 值及表大小
d={
    "one": pd.Series([1.0, 2.0, 3.0]),                           
    "two": pd.Series([1.0, 2.0,3.0,4.0])
}
df = pd.DataFrame(d)

# %%
贵州茅台原始数据 = pd.read_csv(R'data\600519.csv')

# %%
贵州茅台原始数据[['TURNOVER','volume']]
# Out:
#          TURNOVER  volume
# 0      1410347008  406318
# 1       463463008  129647
# 2       194689000   53252
# 3       177558000   48013
# 4        86231000   23231
# ...           ...     ...
# 4089   2694714080   49076
# 4090  10663392512  204397
# 4091   5239853056   96885
# 4092   5581027328   98107
# 4093   5227695104   89157
#
# [4094 rows x 2 columns]

# %%
贵州茅台原始数据 = pd.read_csv(R'data\600519.csv')

# %%
#按列查询数据
贵州茅台原始数据['TURNOVER']
# Out:
# 0        1410347008
# 1         463463008
# 2         194689000
# 3         177558000
# 4          86231000
#            ...
# 4089     2694714080
# 4090    10663392512
# 4091     5239853056
# 4092     5581027328
# 4093     5227695104
# Name: TURNOVER, Length: 4094, dtype: int64

# %%
#按照行索引
贵州茅台原始数据.loc[0]
# Out:
# day            2001/8/27
# STOCK_CODE       6005191
# open               34.51
# close              35.55
# maximum            37.78
# minimum            32.85
# volume            406318
# TURNOVER      1410347008
# Name: 0, dtype: object

# %%
贵州茅台=贵州茅台原始数据.set_index('day')

# %%
#loc索引器

# %%
贵州茅台.loc['2003-08-27',['open','close']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2003-08-27'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\86181\Desktop\33\05-dateframe.ipynb 单元格 16 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/86181/Desktop/33/05-dateframe.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> 贵州茅台.loc['2003-08-27',['open','close']]
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1280, in _LocIndexer._getitem_tuple(self, tup)
#    1278 with suppress(IndexingError):
#    1279     tup = self._expand_ellipsis(tup)
# -> 1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
#    1283 tup = self._validate_tuple_indexer(tup)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1000, in _LocationIndexer._getitem_lowerdim(self, tup)
#     996 for i, key in enumerate(tup):
#     997     if is_label_like(key):
#     998         # We don't need to check for tuples here because those are
#     999         #  caught by the _is_nested_tuple_indexer check above.
# -> 1000         section = self._getitem_axis(key, axis=i)
#    1002         # We should never have a scalar section here, because
#    1003         #  _getitem_lowerdim is only called after a check for
#    1004         #  is_scalar_access, which that would be.
#    1005         if section.ndim == self.ndim:
#    1006             # we're in the middle of slicing through a MultiIndex
#    1007             # revise the key wrt to `section` by inserting an _NS
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
#    1292     # GH#5567 this will fail if the label is not present in the axis.
# -> 1293     return self.obj.xs(label, axis=axis)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py:4095, in NDFrame.xs(self, key, axis, level, drop_level)
#    4093             new_index = index[loc]
#    4094 else:
# -> 4095     loc = index.get_loc(key)
#    4097     if isinstance(loc, np.ndarray):
#    4098         if loc.dtype == np.bool_:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: '2003-08-27'

# %%
#loc索引器#
#单个元素
贵州茅台.loc['2001-08-30']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2001-08-30'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\86181\Desktop\33\05-dateframe.ipynb 单元格 17 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/86181/Desktop/33/05-dateframe.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> #loc索引器#
#       <a href='vscode-notebook-cell:/c%3A/Users/86181/Desktop/33/05-dateframe.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> #单个元素
# ----> <a href='vscode-notebook-cell:/c%3A/Users/86181/Desktop/33/05-dateframe.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> 贵州茅台.loc['2001-08-30']
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
#    1292     # GH#5567 this will fail if the label is not present in the axis.
# -> 1293     return self.obj.xs(label, axis=axis)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py:4095, in NDFrame.xs(self, key, axis, level, drop_level)
#    4093             new_index = index[loc]
#    4094 else:
# -> 4095     loc = index.get_loc(key)
#    4097     if isinstance(loc, np.ndarray):
#    4098         if loc.dtype == np.bool_:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: '2001-08-30'

# %%
条件1=贵州茅台['open']<35
条件2=贵州茅台['close']<35
布尔列表=条件1&条件2
贵州茅台.loc[布尔列表]
# Out:
#             STOCK_CODE   open  close  maximum  minimum  volume   TURNOVER
# day
# 2001/10/17     6005191  34.79  34.20    34.81    33.90   12507   42766000
# 2001/10/18     6005191  34.20  34.04    34.66    33.91    4983   16999000
# 2001/10/19     6005191  34.00  33.50    34.15    33.01   15687   52422000
# 2001/10/22     6005191  33.30  32.79    33.70    32.70    9760   32268000
# 2001/11/8      6005191  33.35  33.70    33.89    32.98    7402   24682000
# ...                ...    ...    ...      ...      ...     ...        ...
# 2004/9/21      6005191  32.09  32.30    32.98    32.09    8374   27222818
# 2004/9/22      6005191  32.03  32.16    32.49    32.03    4348   13965168
# 2004/9/23      6005191  32.11  33.42    33.52    32.11   17667   58219692
# 2004/9/24      6005191  33.60  34.49    35.89    33.60   30981  108295826
# 2004/9/27      6005191  34.95  34.93    35.98    34.50    6067   21339456
#
# [498 rows x 7 columns]

# %%
条件1=贵州茅台['open']<35
条件2=贵州茅台['close']<35
布尔列表=条件1&条件2
贵州茅台.loc[布尔列表]
# Out:
#             STOCK_CODE   open  close  maximum  minimum  volume   TURNOVER
# day
# 2001/10/17     6005191  34.79  34.20    34.81    33.90   12507   42766000
# 2001/10/18     6005191  34.20  34.04    34.66    33.91    4983   16999000
# 2001/10/19     6005191  34.00  33.50    34.15    33.01   15687   52422000
# 2001/10/22     6005191  33.30  32.79    33.70    32.70    9760   32268000
# 2001/11/8      6005191  33.35  33.70    33.89    32.98    7402   24682000
# ...                ...    ...    ...      ...      ...     ...        ...
# 2004/9/21      6005191  32.09  32.30    32.98    32.09    8374   27222818
# 2004/9/22      6005191  32.03  32.16    32.49    32.03    4348   13965168
# 2004/9/23      6005191  32.11  33.42    33.52    32.11   17667   58219692
# 2004/9/24      6005191  33.60  34.49    35.89    33.60   30981  108295826
# 2004/9/27      6005191  34.95  34.93    35.98    34.50    6067   21339456
#
# [498 rows x 7 columns]

# %%
#使用函数作为索引
def condition(pd):
    条件1=pd['open']<35
    条件2=pd['close']<35
    布尔列表=条件1 & 条件2
    return 布尔列表

# %%
贵州茅台.loc[condition]
# Out:
#             STOCK_CODE   open  close  maximum  minimum  volume   TURNOVER
# day
# 2001/10/17     6005191  34.79  34.20    34.81    33.90   12507   42766000
# 2001/10/18     6005191  34.20  34.04    34.66    33.91    4983   16999000
# 2001/10/19     6005191  34.00  33.50    34.15    33.01   15687   52422000
# 2001/10/22     6005191  33.30  32.79    33.70    32.70    9760   32268000
# 2001/11/8      6005191  33.35  33.70    33.89    32.98    7402   24682000
# ...                ...    ...    ...      ...      ...     ...        ...
# 2004/9/21      6005191  32.09  32.30    32.98    32.09    8374   27222818
# 2004/9/22      6005191  32.03  32.16    32.49    32.03    4348   13965168
# 2004/9/23      6005191  32.11  33.42    33.52    32.11   17667   58219692
# 2004/9/24      6005191  33.60  34.49    35.89    33.60   30981  108295826
# 2004/9/27      6005191  34.95  34.93    35.98    34.50    6067   21339456
#
# [498 rows x 7 columns]

# %%
贵州茅台.sample()
# Out:
#             STOCK_CODE  open  close  maximum  minimum  volume  TURNOVER
# day
# 2005/12/26     6005191  44.2  44.21     44.5     43.8    6992  30863111

# %%
贵州茅台.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4094 entries, 2001/8/27 to 2018/11/2
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STOCK_CODE  4094 non-null   int64
#  1   open        4094 non-null   float64
#  2   close       4094 non-null   float64
#  3   maximum     4094 non-null   float64
#  4   minimum     4094 non-null   float64
#  5   volume      4094 non-null   int64
#  6   TURNOVER    4094 non-null   int64
# dtypes: float64(4), int64(3)
# memory usage: 384.9+ KB

# %%
贵州茅台.describe()
# Out:
#        STOCK_CODE         open        close      maximum      minimum  \
# count      4094.0  4094.000000  4094.000000  4094.000000  4094.000000
# mean    6005191.0   182.161910   182.435230   184.879680   179.801353
# std           0.0   165.857882   165.994905   168.082099   163.752065
# min     6005191.0    20.900000    20.880000    21.000000    20.710000
# 25%     6005191.0    47.405000    47.482500    48.222500    46.705000
# 50%     6005191.0   159.930000   159.980000   161.910000   157.875000
# 75%     6005191.0   208.500000   209.457500   212.175000   205.945000
# max     6005191.0   800.000000   799.190000   803.500000   788.880000
#
#               volume      TURNOVER
# count    4094.000000  4.094000e+03
# mean    27092.525892  6.487986e+08
# std     24623.472099  9.550262e+08
# min       238.000000  1.421413e+06
# 25%     10186.750000  6.203505e+07
# 50%     22491.000000  3.727192e+08
# 75%     36759.500000  7.486596e+08
# max    406318.000000  1.066339e+10

# %%
贵州茅台['open'].describe()
# Out:
# count    4094.000000
# mean      182.161910
# std       165.857882
# min        20.900000
# 25%        47.405000
# 50%       159.930000
# 75%       208.500000
# max       800.000000
# Name: open, dtype: float64

# %%
result=贵州茅台['open'].unique()

# %%
result2=贵州茅台['open'].nunique()

# %%
result3=贵州茅台['open'].value_counts()

# %%
df=pd.DataFrame({
    "name":["A","B","C","B","C","A","C"],
    "value":[1,3,7,2,4,3,1]
})
df.groupby("name")["value"].sum()
# Out:
# name
# A     4
# B     5
# C    12
# Name: value, dtype: int64
